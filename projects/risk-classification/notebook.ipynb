# %% [markdown]
# # Risk Classification
#
# **Objective:** Classify project tasks as high/medium/low risk using logistic regression.
#
# **Features:**
# - Task complexity score
# - Dependencies count
# - Resource availability
# - Historical delay rate
#
# **Target:** Risk level (High/Medium/Low)
#
# ---
#
# ## Milestones
# - [ ] Data loaded (+10 pts)
# - [ ] Data preprocessed (+10 pts)
# - [ ] Model trained (+10 pts)
# - [ ] Model evaluated (+10 pts)
# - [ ] Visualizations complete (+10 pts)
# - [ ] Notebook complete (+25 pts)
# - [ ] Accuracy >80% (+10 bonus pts)
#
# **Total possible: 85 points**

# %% [markdown]
# ## 1. Setup & Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
import joblib

np.random.seed(42)

# %% [markdown]
# ## 2. Data Loading

# %%
# TODO: Load dataset
# df = pd.read_csv('data.csv')
# df.head()

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %%
# TODO: EDA
# df['risk_level'].value_counts()

# %% [markdown]
# ## 4. Data Preprocessing

# %%
# TODO: Encode labels and prepare features
# le = LabelEncoder()
# df['risk_encoded'] = le.fit_transform(df['risk_level'])

# %% [markdown]
# ## 5. Model Training

# %%
# TODO: Train logistic regression
# model = LogisticRegression(multi_class='multinomial', max_iter=1000)
# model.fit(X_train, y_train)

# %% [markdown]
# ## 6. Model Evaluation

# %%
# TODO: Evaluate
# print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
# print(classification_report(y_test, y_pred))

# %% [markdown]
# ## 7. Visualizations

# %%
# TODO: Confusion matrix heatmap
# sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)

# %% [markdown]
# ## 8. Save Model

# %%
# TODO: Save model
# joblib.dump(model, 'risk_classifier.pkl')

# %% [markdown]
# ## 9. Conclusions
#
# **Key Findings:**
# -
#
# **Model Performance:**
# - Accuracy:
# - Precision/Recall:
#
# **Badge Earned:** :dart: Accuracy Ace (if >80%)
