# %% [markdown]
# # Performance Clustering
#
# **Objective:** Identify project performance patterns using K-means clustering.
#
# **Features:**
# - Cost Performance Index (CPI)
# - Schedule Performance Index (SPI)
# - Team velocity
# - Defect density
#
# **Target:** Discover natural groupings (no labels)
#
# ---
#
# ## Milestones
# - [ ] Data loaded (+10 pts)
# - [ ] Data preprocessed & scaled (+10 pts)
# - [ ] Elbow method analysis (+10 pts)
# - [ ] Model trained (+10 pts)
# - [ ] Silhouette score calculated (+10 pts)
# - [ ] Cluster visualizations (+10 pts)
# - [ ] Notebook complete (+25 pts)
#
# **Total possible: 85 points**

# %% [markdown]
# ## 1. Setup & Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

np.random.seed(42)

# %% [markdown]
# ## 2. Data Loading

# %%
# TODO: Load dataset
# df = pd.read_csv('data.csv')
# df.head()

# %% [markdown]
# ## 3. Data Preprocessing

# %%
# TODO: Scale features (important for clustering!)
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## 4. Elbow Method - Finding Optimal K

# %%
# TODO: Elbow method
# inertias = []
# K_range = range(2, 11)
# for k in K_range:
#     kmeans = KMeans(n_clusters=k, random_state=42)
#     kmeans.fit(X_scaled)
#     inertias.append(kmeans.inertia_)

# %% [markdown]
# ## 5. Model Training

# %%
# TODO: Train with optimal K
# kmeans = KMeans(n_clusters=optimal_k, random_state=42)
# clusters = kmeans.fit_predict(X_scaled)

# %% [markdown]
# ## 6. Model Evaluation

# %%
# TODO: Calculate silhouette score
# sil_score = silhouette_score(X_scaled, clusters)
# print(f'Silhouette Score: {sil_score}')

# %% [markdown]
# ## 7. Visualizations

# %%
# TODO: Scatter plot of clusters
# plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters, cmap='viridis')
# plt.xlabel('CPI (scaled)')
# plt.ylabel('SPI (scaled)')
# plt.title('Project Performance Clusters')
# plt.show()

# %% [markdown]
# ## 8. Cluster Analysis

# %%
# TODO: Analyze cluster characteristics
# df['cluster'] = clusters
# df.groupby('cluster').mean()

# %% [markdown]
# ## 9. Conclusions
#
# **Clusters Identified:**
# - Cluster 0:
# - Cluster 1:
# - Cluster 2:
#
# **Silhouette Score:**
#
# **PM Insights:**
# -
#
# **Badge Earned:** :jigsaw: Cluster Commander
